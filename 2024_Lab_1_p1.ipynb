# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh-Lalla/Prob-Stats_Jio/blob/main/2024_Lab_1_p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Union
example_set_1 = {1,2,3}
example_set_2 = {'a','b','c'}
#Method 1
example_union_1 = example_set_1.union(example_set_2)
print('Printing union set using method 1 :', example_union_1)
# Method 2:
example_union_2 = example_set_1|example_set_2
print('Printing union set using method 2 :', example_union_2)
# Out:
# Printing union set using method 1 : {'c', 1, 2, 3, 'a', 'b'}
# Printing union set using method 2 : {'c', 1, 2, 3, 'a', 'b'}

# %%
#Intersection
example_set_1 = {1,2,3}
example_set_2 = {3,'b','c'}
#Method 1
example_intersection_1 = example_set_1.intersection(example_set_2)
print('Printing intersection set using method 1 :', example_intersection_1)
# Method 2:
example_intersection_2 = example_set_1 & example_set_2
print('Printing intersection set using method 2 :', example_intersection_2)
# Out:
# Printing intersection set using method 1 : {3}
# Printing intersection set using method 2 : {3}

# %%
# Set Difference
#Intersection
example_set_1 = {1,2,3}
example_set_2 = {3,'b','c'}
#Method 1
example_diff_1 = example_set_1.difference(example_set_2)
print('Printing set difference using method 1 :', example_diff_1)
# Method 2:
example_diff_2 = example_set_1 - example_set_2
print('Printing set difference using method 2 :', example_diff_2)
# Out:
# Printing set difference using method 1 : {1, 2}
# Printing set difference using method 2 : {1, 2}

# %%
import numpy as np

# %%
#Define a function to simulate coin tosses
def coin_toss():
    if np.random.random()>= 0.5:
        return 'H'
    else:
        return 'T'

# %%
# Simulate the coin toss and store the outcomes in a dictionary
num_tosses = 10
toss_results = {}
for i in range(num_tosses):
    toss_results[i] = coin_toss()
toss_results
# Out:
# {0: 'H',
#  1: 'T',
#  2: 'T',
#  3: 'T',
#  4: 'T',
#  5: 'H',
#  6: 'H',
#  7: 'T',
#  8: 'H',
#  9: 'H'}

# %%
# Count the number of heads and tails
print('Heads : ', sum([x=='H' for x in toss_results.values()]))
print('Tails : ', sum([x=='T' for x in toss_results.values()]))
# Out:
# Heads :  5
# Tails :  5

# %%
# If toss many times, what fraction of times will we get heads?
toss_results_list = [coin_toss() for x in range(10000)]

print('Heads : ', sum([x=='H' for x in toss_results_list]))
print('Tails : ', sum([x=='T' for x in toss_results_list]))
# Out:
# Heads :  5043
# Tails :  4957

# %%
def die_roll():
    sample_space = [1,2,3,4,5,6]
    proba = [1/len(sample_space) for x in range(len(sample_space))] # All throws are equally likely
    return np.random.choice(sample_space, p=proba)

# %%
die_roll()
# Out:
# 2

# %%
from collections import Counter
dict(Counter([die_roll() for x in range(1000)]))
# Out:
# {4: 167, 3: 144, 5: 172, 2: 191, 1: 174, 6: 152}

# %% [markdown]
# Event space

# %%
import matplotlib.pyplot as plt

# %%
# If a die is thrown many times, let's plot the number of times each face appear
number_throws = 100000
die_throw = Counter([die_roll() for x in range(number_throws)])
plt.bar(x = die_throw.keys(), height = die_throw.values())
plt.show()

# %%
# Lets sum the faces from two dice rolled many times
number_throws = 1000
[die_roll()+die_roll() for x in range(number_throws)]
# Out:
# [5,
#  11,
#  6,
#  3,
#  9,
#  12,
#  10,
#  7,
#  3,
#  8,
#  4,
#  7,
#  10,
#  3,
#  7,
#  10,
#  7,
#  7,
#  6,
#  8,
#  10,
#  4,
#  5,
#  8,
#  8,
#  10,
#  5,
#  4,
#  10,
#  7,
#  11,
#  5,
#  7,
#  8,
#  8,
#  7,
#  10,
#  6,
#  5,
#  9,
#  4,
#  9,
#  11,
#  3,
#  5,
#  5,
#  4,
#  6,
#  5,
#  10,
#  9,
#  6,
#  7,
#  8,
#  2,
#  6,
#  7,
#  9,
#  10,
#  11,
#  5,
#  5,
#  10,
#  3,
#  8,
#  2,
#  10,
#  11,
#  5,
#  7,
#  4,
#  2,
#  11,
#  8,
#  5,
#  7,
#  7,
#  5,
#  8,
#  10,
#  3,
#  9,
#  7,
#  4,
#  6,
#  10,
#  7,
#  3,
#  8,
#  7,
#  9,
#  10,
#  5,
#  9,
#  8,
#  9,
#  11,
#  8,
#  8,
#  10,
#  4,
#  4,
#  2,
#  6,
#  12,
#  3,
#  6,
#  4,
#  5,
#  7,
#  3,
#  5,
#  6,
#  5,
#  11,
#  4,
#  5,
#  10,
#  11,
#  7,
#  7,
#  6,
#  11,
#  5,
#  7,
#  6,
#  9,
#  12,
#  10,
#  7,
#  10,
#  5,
#  11,
#  9,
#  4,
#  9,
#  7,
#  7,
#  2,
#  10,
#  8,
#  9,
#  9,
#  7,
#  5,
#  9,
#  5,
#  5,
#  8,
#  4,
#  9,
#  3,
#  8,
#  4,
#  10,
#  7,
#  7,
#  7,
#  9,
#  6,
#  8,
#  7,
#  9,
#  5,
#  9,
#  6,
#  7,
#  9,
#  10,
#  12,
#  7,
#  10,
#  7,
#  7,
#  9,
#  7,
#  6,
#  7,
#  7,
#  7,
#  12,
#  6,
#  5,
#  9,
#  2,
#  6,
#  7,
#  10,
#  6,
#  9,
#  9,
#  9,
#  4,
#  8,
#  4,
#  11,
#  7,
#  10,
#  5,
#  7,
#  4,
#  9,
#  4,
#  10,
#  2,
#  8,
#  7,
#  11,
#  12,
#  6,
#  8,
#  7,
#  7,
#  4,
#  12,
#  9,
#  6,
#  11,
#  10,
#  9,
#  6,
#  5,
#  9,
#  5,
#  8,
#  12,
#  5,
#  9,
#  9,
#  6,
#  6,
#  4,
#  3,
#  2,
#  7,
#  2,
#  3,
#  10,
#  7,
#  7,
#  11,
#  5,
#  8,
#  3,
#  7,
#  5,
#  11,
#  10,
#  9,
#  5,
#  10,
#  7,
#  2,
#  10,
#  9,
#  12,
#  8,
#  3,
#  7,
#  3,
#  5,
#  9,
#  7,
#  7,
#  3,
#  10,
#  6,
#  8,
#  9,
#  6,
#  7,
#  10,
#  6,
#  5,
#  3,
#  5,
#  3,
#  10,
#  6,
#  5,
#  7,
#  9,
#  2,
#  9,
#  9,
#  4,
#  9,
#  4,
#  3,
#  7,
#  9,
#  3,
#  2,
#  3,
#  5,
#  10,
#  9,
#  7,
#  8,
#  3,
#  4,
#  9,
#  6,
#  7,
#  10,
#  9,
#  4,
#  4,
#  4,
#  11,
#  4,
#  6,
#  8,
#  11,
#  10,
#  4,
#  2,
#  11,
#  11,
#  11,
#  5,
#  6,
#  4,
#  5,
#  4,
#  7,
#  7,
#  9,
#  6,
#  5,
#  10,
#  8,
#  11,
#  9,
#  4,
#  11,
#  10,
#  5,
#  11,
#  6,
#  10,
#  6,
#  7,
#  5,
#  9,
#  7,
#  10,
#  7,
#  10,
#  6,
#  6,
#  7,
#  7,
#  5,
#  8,
#  6,
#  7,
#  6,
#  8,
#  7,
#  6,
#  8,
#  6,
#  8,
#  7,
#  8,
#  9,
#  9,
#  6,
#  5,
#  7,
#  6,
#  10,
#  9,
#  9,
#  9,
#  10,
#  5,
#  8,
#  8,
#  7,
#  6,
#  8,
#  7,
#  8,
#  6,
#  5,
#  6,
#  3,
#  3,
#  8,
#  6,
#  10,
#  11,
#  4,
#  7,
#  5,
#  11,
#  5,
#  11,
#  6,
#  6,
#  6,
#  3,
#  7,
#  5,
#  12,
#  4,
#  9,
#  10,
#  4,
#  6,
#  10,
#  6,
#  4,
#  5,
#  4,
#  5,
#  11,
#  9,
#  8,
#  7,
#  10,
#  5,
#  11,
#  4,
#  4,
#  4,
#  5,
#  5,
#  5,
#  12,
#  6,
#  5,
#  7,
#  7,
#  2,
#  11,
#  4,
#  7,
#  6,
#  5,
#  9,
#  4,
#  5,
#  3,
#  3,
#  3,
#  7,
#  7,
#  10,
#  6,
#  4,
#  9,
#  10,
#  6,
#  7,
#  6,
#  9,
#  5,
#  10,
#  10,
#  10,
#  11,
#  6,
#  6,
#  3,
#  4,
#  7,
#  5,
#  4,
#  9,
#  12,
#  5,
#  9,
#  4,
#  8,
#  8,
#  8,
#  8,
#  6,
#  5,
#  2,
#  7,
#  3,
#  11,
#  7,
#  6,
#  7,
#  6,
#  3,
#  5,
#  6,
#  7,
#  8,
#  8,
#  5,
#  12,
#  11,
#  11,
#  5,
#  4,
#  9,
#  3,
#  6,
#  3,
#  10,
#  4,
#  4,
#  6,
#  8,
#  2,
#  10,
#  10,
#  10,
#  6,
#  5,
#  5,
#  7,
#  8,
#  7,
#  10,
#  4,
#  11,
#  10,
#  8,
#  9,
#  4,
#  5,
#  12,
#  8,
#  3,
#  8,
#  4,
#  7,
#  9,
#  7,
#  6,
#  6,
#  9,
#  6,
#  6,
#  7,
#  7,
#  4,
#  6,
#  6,
#  9,
#  5,
#  7,
#  6,
#  5,
#  5,
#  9,
#  7,
#  4,
#  9,
#  8,
#  12,
#  10,
#  11,
#  6,
#  6,
#  9,
#  7,
#  4,
#  7,
#  11,
#  9,
#  7,
#  11,
#  8,
#  10,
#  8,
#  8,
#  6,
#  6,
#  10,
#  12,
#  8,
#  5,
#  7,
#  6,
#  8,
#  4,
#  7,
#  9,
#  8,
#  9,
#  9,
#  8,
#  11,
#  10,
#  8,
#  8,
#  5,
#  3,
#  11,
#  10,
#  7,
#  8,
#  5,
#  4,
#  10,
#  7,
#  8,
#  6,
#  8,
#  10,
#  7,
#  6,
#  11,
#  8,
#  12,
#  7,
#  4,
#  7,
#  3,
#  7,
#  10,
#  8,
#  11,
#  6,
#  7,
#  5,
#  6,
#  7,
#  9,
#  6,
#  8,
#  8,
#  6,
#  6,
#  4,
#  8,
#  2,
#  2,
#  7,
#  7,
#  5,
#  10,
#  4,
#  6,
#  10,
#  6,
#  6,
#  12,
#  7,
#  7,
#  7,
#  4,
#  10,
#  8,
#  9,
#  5,
#  6,
#  5,
#  4,
#  11,
#  7,
#  7,
#  6,
#  4,
#  9,
#  6,
#  10,
#  7,
#  10,
#  9,
#  8,
#  6,
#  9,
#  8,
#  12,
#  6,
#  8,
#  8,
#  8,
#  7,
#  5,
#  7,
#  4,
#  7,
#  2,
#  8,
#  10,
#  6,
#  10,
#  8,
#  11,
#  9,
#  7,
#  9,
#  6,
#  5,
#  4,
#  12,
#  9,
#  8,
#  6,
#  8,
#  9,
#  6,
#  4,
#  9,
#  6,
#  4,
#  9,
#  4,
#  6,
#  9,
#  6,
#  10,
#  7,
#  11,
#  8,
#  4,
#  9,
#  11,
#  9,
#  7,
#  8,
#  11,
#  9,
#  7,
#  7,
#  11,
#  8,
#  7,
#  11,
#  3,
#  8,
#  5,
#  4,
#  3,
#  11,
#  2,
#  10,
#  9,
#  4,
#  3,
#  4,
#  7,
#  7,
#  8,
#  3,
#  11,
#  6,
#  4,
#  7,
#  10,
#  4,
#  7,
#  6,
#  8,
#  3,
#  6,
#  9,
#  7,
#  9,
#  10,
#  5,
#  6,
#  10,
#  8,
#  9,
#  12,
#  5,
#  9,
#  9,
#  7,
#  6,
#  7,
#  4,
#  10,
#  5,
#  4,
#  6,
#  8,
#  8,
#  8,
#  3,
#  9,
#  8,
#  11,
#  8,
#  8,
#  9,
#  7,
#  7,
#  5,
#  7,
#  11,
#  6,
#  6,
#  3,
#  8,
#  6,
#  10,
#  2,
#  6,
#  8,
#  4,
#  9,
#  5,
#  6,
#  5,
#  7,
#  4,
#  9,
#  7,
#  7,
#  10,
#  12,
#  8,
#  9,
#  10,
#  8,
#  7,
#  9,
#  5,
#  6,
#  12,
#  2,
#  9,
#  8,
#  10,
#  8,
#  6,
#  9,
#  12,
#  5,
#  10,
#  5,
#  8,
#  9,
#  5,
#  7,
#  11,
#  6,
#  4,
#  9,
#  9,
#  10,
#  6,
#  3,
#  9,
#  11,
#  6,
#  7,
#  12,
#  8,
#  7,
#  5,
#  10,
#  9,
#  4,
#  4,
#  10,
#  8,
#  11,
#  6,
#  8,
#  12,
#  5,
#  5,
#  7,
#  5,
#  5,
#  11,
#  7,
#  5,
#  6,
#  11,
#  8,
#  7,
#  9,
#  7,
#  12,
#  6,
#  9,
#  2,
#  7,
#  9,
#  9,
#  5,
#  7,
#  8,
#  5,
#  10,
#  7,
#  5,
#  8,
#  10,
#  8,
#  9,
#  7,
#  8,
#  7,
#  6,
#  8,
#  8,
#  9,
#  8,
#  8,
#  7,
#  8,
#  6,
#  3,
#  6,
#  5,
#  9,
#  8,
#  5,
#  9,
#  9,
#  5,
#  8,
#  12,
#  8,
#  11,
#  5,
#  2,
#  4,
#  9,
#  5,
#  5,
#  4,
#  7,
#  8,
#  3,
#  7,
#  11,
#  4,
#  3,
#  7,
#  7,
#  8,
#  6,
#  10,
#  10,
#  7,
#  10,
#  7,
#  4,
#  6,
#  5,
#  11,
#  8,
#  4,
#  6,
#  10,
#  9,
#  10,
#  6,
#  4,
#  11,
#  10,
#  6,
#  6,
#  7,
#  10,
#  11,
#  5,
#  7,
#  11,
#  4,
#  6,
#  8,
#  5,
#  8,
#  6,
#  4,
#  7,
#  5,
#  5,
#  9,
#  10,
#  8,
#  7,
#  8,
#  10,
#  10,
#  5,
#  9,
#  6,
#  12,
#  9,
#  4,
#  8,
#  11,
#  6,
#  8,
#  8,
#  11,
#  10,
#  7,
#  8,
#  6,
#  6]

# %%
die_sum = {k:v for k,v in sorted(Counter([die_roll()+die_roll() for x in range(number_throws)]).items(), key = lambda item: item[0])}
print(die_sum)
# Out:
# {2: 24, 3: 52, 4: 100, 5: 109, 6: 138, 7: 166, 8: 130, 9: 94, 10: 88, 11: 62, 12: 37}

# %%
# Let's plot the values of the sum
plt.bar(x = die_sum.keys(), height = die_sum.values())
plt.show()

# %% [markdown]
# What is the probability of winning a lottery where there are 100 tickets issued and bought? Why is the probability not half?

# %%
# Lets write a function to pick a winning ticket number
def lottery(number_of_tickets):
    tickets = [x for x in range(1,number_of_tickets+1)] # Suppose tickets are numbered from 1 to N
    proba = [1/len(tickets) for x in range(len(tickets))]
    return np.random.choice(tickets, p=proba)

# %%
# If there are 100 tickets, and you have bought ticket number 5, what is the probability of your win?

# Let us run the lottery many times
number_of_times = 10000
winning_numbers = [lottery(100) for x in range(number_of_times)]

# Let us check how many times 5 was the winning number
wins = sum([x==5 for x in winning_numbers])

# What can we say about the probability of winning?
wins/number_of_times
# Out:
# 0.0106

# %% [markdown]
# Question: What is the probability of getting a three or a seven when a fair die is rolled?

# %%
rolls = [die_roll() for x in range(100000)]
(rolls.count(7)+rolls.count(3))/len(rolls)
# Out:
# 0.16535

# %% [markdown]
# Question: What is the probability of getting two heads when a coin is tossed twice?

# %%
#Define a function to simulate coin tosses
def coin_toss():
    if np.random.random()>= 0.5:
        return 1
    else:
        return 0

# %%
tosses = [coin_toss()*coin_toss() for x in range(10000)]
sum(tosses)/len(tosses)
# Out:
# 0.2484

# %% [markdown]
# Question: The participants of a course include 7 men and 10 women from India, 5 men and 7 women from the USA. If a participant is picked at random, what is the probability that the participant is Indian or a man?

# %%
def participant_selector(m_i,w_i,m_u,w_u):
    # Let's create the sample space with man_india, woman_india, man_usa and woman_usa to refer to the participants
    participants = ['india_man']*m_i+['india_woman']*w_i+['usa_man']*m_u+['usa_woman']*w_u
    np.random.shuffle(participants)
    #print(participants)
    proba = [1/len(participants) for x in range(len(participants))]
    return np.random.choice(participants, p=proba)

# %%
# Let us run the participant selection many times
number_of_times = 1000
selected_participants = [participant_selector(7,10,5,7) for x in range(number_of_times)]

# Number of participants who are either indian or men = number of indians + number of men - number of indian men

# Number of Indians
n_indians = sum(['india' in x for x in selected_participants])
# Number of men
n_men = sum(['_man' in x for x in selected_participants])
# Number of men who are indians
n_indian_men = sum(['india_man' in x for x in selected_participants])

n_indian_or_men = n_indians + n_men - n_indian_men

# Probability
n_indian_or_men/len(selected_participants)
# Out:
# 0.759

# %% [markdown]
# Probability of complements:
#
# Question: A bag contains 2 red balls, 3 blue balls and 2 green balls. What is the probability of picking a ball that's not red

# %%
def ball_from_bag(red,blue,green):
    # Let's create the sample space
    bag = ['red']*red+['blue']*blue+['green']*green
    np.random.shuffle(bag)
    #print(bag)
    proba = [1/len(bag) for x in range(len(bag))]
    return np.random.choice(bag, p=proba)

# %%
# Let us run the selection many times
number_of_times = 10000
selections = [ball_from_bag(2,3,2) for x in range(number_of_times)]

# Number of selections that are not red
not_red = sum([x!='red' for x in selections])

# Probability
not_red/len(selections)
# Out:
# 0.7151

# %% [markdown]
# Dependent Events and conditional probability and joint probability

# %% [markdown]
# 1. A bag contains 4 red marbles and 3 blue marbles. You draw a marble from the bag. The marble drawn is blue. You return the marble to the bag and draw another. What is the proability that the second marble drawn is red?

# %%
def ball_from_bag(red,blue,green):
    # Let's create the sample space
    bag = ['red']*red+['blue']*blue+['green']*green
    #print(bag)
    np.random.shuffle(bag)
    #print(bag)
    proba = [1/len(bag) for x in range(len(bag))]
    return np.random.choice(bag, p=proba)

# %%
# Let us run this experiment multiple times
number_of_times = 100000
# First selection
selections_1 = [ball_from_bag(4,3,0) for x in range(number_of_times)]

# Second selection after returning the first marble
selections_2 = [ball_from_bag(4,3,0) for x in range(number_of_times)]

#Probability of red in second draw
red = sum([x=='red' for x in selections_2]) # Number of reds
red/len(selections_2)
# Out:
# 0.573

# %% [markdown]
# 2. A bag contains 4 red marbles and 3 blue marbles. You draw a marble from the bag. The marble drawn is blue. You draw another marble. What is the proability that the second marble drawn is red?

# %%
def ball_from_bag(red,blue,green):
    # Let's create the sample space
    bag = ['red']*red+['blue']*blue+['green']*green
    #print(bag)
    np.random.shuffle(bag)
    #print(bag)
    proba = [1/len(bag) for x in range(len(bag))]
    return np.random.choice(bag, p=proba)

# %%
# Let us run this experiment multiple times
number_of_times = 1000
# First selection
selections_1 = [ball_from_bag(4,3,0) for x in range(number_of_times)]

# Second selecttion. This time we have 1 blue less
selections_2 = [ball_from_bag(4,2,0) for x in range(number_of_times)]

#Probability of red in second draw
red = sum([x=='red' for x in selections_2]) # Number of reds
red/len(selections_2)
# Out:
# 0.687

# %%
# p(r/b)

(3/7)*(4/6)/(3/7)
# Out:
# 0.6666666666666666

# %% [markdown]
# 3. A bag contains 4 red marbles and 3 blue marbles. You draw two marbles from the bag, one after the other. What is the probability that the second marble is blue?

# %%
def ball_from_bag_2(red,blue,green):
    # Let's create the sample space
    bag = ['red']*red+['blue']*blue+['green']*green
    #print(bag)
    np.random.shuffle(bag)
    #print(bag)
    proba = [1/len(bag) for x in range(len(bag))]
    pick1 = np.random.choice(bag, p=proba)
    #print(pick1)
    # Remove pick 1 from bag since we are not returning it, before picking next
    bag = ['red']*(red - 1*(pick1=='red')) + ['blue']*(blue - 1*(pick1=='blue')) + ['green']*(green - 1*(pick1=='green'))
    #print(bag)
    proba = [1/len(bag) for x in range(len(bag))]
    pick2 = np.random.choice(bag, p=proba)
    return [pick1, pick2]

# %%
# Let us run this experiment multiple times
number_of_times = 1000
selections_1 = [ball_from_bag_2(4,3,0) for x in range(number_of_times)]
#print(selections_1)
second_blue = [x for x in selections_1 if x[1]=='blue'] # Finds cases where the second one is blue
#print(second_blue)
len(second_blue)/len(selections_1)
# Out:
# 0.432

# %%
(4/7)*(3/6) + (3/7)*(2/6)
# Out:
# 0.42857142857142855

# %% [markdown]
# Bayes Theorem

# %% [markdown]
# Question: A bag contains 4 red marbles and 3 blue marbles. You draw two marble from the bag, one by one. The second marble drawn is blue. What is the probability that the first marble drawn was red?

# %%
first_red = [x for x in second_blue if x[0]=='red']
len(first_red)/len(second_blue)
# Out:
# 0.6550925925925926

# %%
(4/7)*(3/6)/((4/7)*(3/6) + (3/7)*(2/6))
# Out:
# 0.6666666666666666

# %% [markdown]
# Question:
# Given the following points, What is the probability that X has a disease D if X has a positive test result?
#
# 1. One percent of X have D.
# 2. Ninety percent of X who have D test positive.
# 3. Eight percent of X will have false positives.

# %%
0.9*0.01/(0.9*0.01 + 0.08*0.99)
# Out:
# 0.10204081632653063

# %%
def disease_given_test(n,p,tp_given_d,fp):
    print('Population : ', n)
    cases = [np.random.random()<=p for x in range(n)]
    #print(cases)
    number_cases = sum(cases)
    print('Number of cases : ',number_cases)
    correct_test_positive = [np.random.random()<=tp_given_d for x in range(number_cases)]
    #print(correct_test_positive)
    number_correct_positives = sum(correct_test_positive)
    print('Number of correct test positives : ',number_correct_positives)
    incorrect_test_positive = [np.random.random()<fp for x in range(n-number_cases)]
    #print(incorrect_test_positive)
    number_incorrect_positive = sum(incorrect_test_positive)
    print('Number of incorrect test positives : ',number_incorrect_positive)
    total_positive = number_correct_positives+number_incorrect_positive
    print('Total positives : ',total_positive)
    print('Probability of disease given test says positive : ',number_correct_positives/total_positive)
    print('-'*50)
    return number_correct_positives/total_positive

# %%
disease_given_test(10000,0.01,0.9,0.08)
# Out:
# Population :  10000
# Number of cases :  108
# Number of correct test positives :  98
# Number of incorrect test positives :  773
# Total positives :  871
# Probability of disease given test says positive :  0.11251435132032148
# --------------------------------------------------
# 0.11251435132032148

# %%
#Let us run this multiple times
n_times = 1000
p_disease_given_test_positive = [disease_given_test(1000,0.01,0.9,0.08) for x in range(n_times)]
# Out:
# Streaming output truncated to the last 5000 lines.
# Probability of disease given test says positive :  0.047619047619047616
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  10
# Number of incorrect test positives :  68
# Total positives :  78
# Probability of disease given test says positive :  0.1282051282051282
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  11
# Number of incorrect test positives :  89
# Total positives :  100
# Probability of disease given test says positive :  0.11
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  8
# Number of incorrect test positives :  91
# Total positives :  99
# Probability of disease given test says positive :  0.08080808080808081
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  6
# Number of incorrect test positives :  70
# Total positives :  76
# Probability of disease given test says positive :  0.07894736842105263
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  65
# Total positives :  76
# Probability of disease given test says positive :  0.14473684210526316
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  90
# Total positives :  99
# Probability of disease given test says positive :  0.09090909090909091
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  87
# Total positives :  96
# Probability of disease given test says positive :  0.09375
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  7
# Number of incorrect test positives :  96
# Total positives :  103
# Probability of disease given test says positive :  0.06796116504854369
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  5
# Number of incorrect test positives :  63
# Total positives :  68
# Probability of disease given test says positive :  0.07352941176470588
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  4
# Number of incorrect test positives :  68
# Total positives :  72
# Probability of disease given test says positive :  0.05555555555555555
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  6
# Number of incorrect test positives :  86
# Total positives :  92
# Probability of disease given test says positive :  0.06521739130434782
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  6
# Number of incorrect test positives :  74
# Total positives :  80
# Probability of disease given test says positive :  0.075
# --------------------------------------------------
# Population :  1000
# Number of cases :  15
# Number of correct test positives :  14
# Number of incorrect test positives :  76
# Total positives :  90
# Probability of disease given test says positive :  0.15555555555555556
# --------------------------------------------------
# Population :  1000
# Number of cases :  17
# Number of correct test positives :  15
# Number of incorrect test positives :  75
# Total positives :  90
# Probability of disease given test says positive :  0.16666666666666666
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  80
# Total positives :  89
# Probability of disease given test says positive :  0.10112359550561797
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  48
# Total positives :  57
# Probability of disease given test says positive :  0.15789473684210525
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  79
# Total positives :  88
# Probability of disease given test says positive :  0.10227272727272728
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  11
# Number of incorrect test positives :  86
# Total positives :  97
# Probability of disease given test says positive :  0.1134020618556701
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  7
# Number of incorrect test positives :  78
# Total positives :  85
# Probability of disease given test says positive :  0.08235294117647059
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  82
# Total positives :  90
# Probability of disease given test says positive :  0.08888888888888889
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  9
# Number of incorrect test positives :  85
# Total positives :  94
# Probability of disease given test says positive :  0.09574468085106383
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  6
# Number of incorrect test positives :  72
# Total positives :  78
# Probability of disease given test says positive :  0.07692307692307693
# --------------------------------------------------
# Population :  1000
# Number of cases :  16
# Number of correct test positives :  15
# Number of incorrect test positives :  76
# Total positives :  91
# Probability of disease given test says positive :  0.16483516483516483
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  11
# Number of incorrect test positives :  86
# Total positives :  97
# Probability of disease given test says positive :  0.1134020618556701
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  5
# Number of incorrect test positives :  73
# Total positives :  78
# Probability of disease given test says positive :  0.0641025641025641
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  81
# Total positives :  90
# Probability of disease given test says positive :  0.1
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  88
# Total positives :  99
# Probability of disease given test says positive :  0.1111111111111111
# --------------------------------------------------
# Population :  1000
# Number of cases :  14
# Number of correct test positives :  13
# Number of incorrect test positives :  77
# Total positives :  90
# Probability of disease given test says positive :  0.14444444444444443
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  90
# Total positives :  100
# Probability of disease given test says positive :  0.1
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  80
# Total positives :  89
# Probability of disease given test says positive :  0.10112359550561797
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  8
# Number of incorrect test positives :  90
# Total positives :  98
# Probability of disease given test says positive :  0.08163265306122448
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  8
# Number of incorrect test positives :  87
# Total positives :  95
# Probability of disease given test says positive :  0.08421052631578947
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  84
# Total positives :  92
# Probability of disease given test says positive :  0.08695652173913043
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  8
# Number of incorrect test positives :  64
# Total positives :  72
# Probability of disease given test says positive :  0.1111111111111111
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  8
# Number of incorrect test positives :  66
# Total positives :  74
# Probability of disease given test says positive :  0.10810810810810811
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  5
# Number of incorrect test positives :  82
# Total positives :  87
# Probability of disease given test says positive :  0.05747126436781609
# --------------------------------------------------
# Population :  1000
# Number of cases :  18
# Number of correct test positives :  17
# Number of incorrect test positives :  85
# Total positives :  102
# Probability of disease given test says positive :  0.16666666666666666
# --------------------------------------------------
# Population :  1000
# Number of cases :  15
# Number of correct test positives :  14
# Number of incorrect test positives :  75
# Total positives :  89
# Probability of disease given test says positive :  0.15730337078651685
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  7
# Number of incorrect test positives :  81
# Total positives :  88
# Probability of disease given test says positive :  0.07954545454545454
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  80
# Total positives :  89
# Probability of disease given test says positive :  0.10112359550561797
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  5
# Number of incorrect test positives :  83
# Total positives :  88
# Probability of disease given test says positive :  0.056818181818181816
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  92
# Total positives :  102
# Probability of disease given test says positive :  0.09803921568627451
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  7
# Number of incorrect test positives :  82
# Total positives :  89
# Probability of disease given test says positive :  0.07865168539325842
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  78
# Total positives :  88
# Probability of disease given test says positive :  0.11363636363636363
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  10
# Number of incorrect test positives :  82
# Total positives :  92
# Probability of disease given test says positive :  0.10869565217391304
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  13
# Number of incorrect test positives :  83
# Total positives :  96
# Probability of disease given test says positive :  0.13541666666666666
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  85
# Total positives :  95
# Probability of disease given test says positive :  0.10526315789473684
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  77
# Total positives :  85
# Probability of disease given test says positive :  0.09411764705882353
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  9
# Number of incorrect test positives :  78
# Total positives :  87
# Probability of disease given test says positive :  0.10344827586206896
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  86
# Total positives :  96
# Probability of disease given test says positive :  0.10416666666666667
# --------------------------------------------------
# Population :  1000
# Number of cases :  16
# Number of correct test positives :  13
# Number of incorrect test positives :  85
# Total positives :  98
# Probability of disease given test says positive :  0.1326530612244898
# --------------------------------------------------
# Population :  1000
# Number of cases :  16
# Number of correct test positives :  13
# Number of incorrect test positives :  72
# Total positives :  85
# Probability of disease given test says positive :  0.15294117647058825
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  10
# Number of incorrect test positives :  92
# Total positives :  102
# Probability of disease given test says positive :  0.09803921568627451
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  8
# Number of incorrect test positives :  84
# Total positives :  92
# Probability of disease given test says positive :  0.08695652173913043
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  12
# Number of incorrect test positives :  81
# Total positives :  93
# Probability of disease given test says positive :  0.12903225806451613
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  9
# Number of incorrect test positives :  68
# Total positives :  77
# Probability of disease given test says positive :  0.11688311688311688
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  9
# Number of incorrect test positives :  87
# Total positives :  96
# Probability of disease given test says positive :  0.09375
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  7
# Number of incorrect test positives :  92
# Total positives :  99
# Probability of disease given test says positive :  0.0707070707070707
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  12
# Number of incorrect test positives :  74
# Total positives :  86
# Probability of disease given test says positive :  0.13953488372093023
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  11
# Number of incorrect test positives :  74
# Total positives :  85
# Probability of disease given test says positive :  0.12941176470588237
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  5
# Number of incorrect test positives :  84
# Total positives :  89
# Probability of disease given test says positive :  0.056179775280898875
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  78
# Total positives :  87
# Probability of disease given test says positive :  0.10344827586206896
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  84
# Total positives :  95
# Probability of disease given test says positive :  0.11578947368421053
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  90
# Total positives :  98
# Probability of disease given test says positive :  0.08163265306122448
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  83
# Total positives :  89
# Probability of disease given test says positive :  0.06741573033707865
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  9
# Number of incorrect test positives :  75
# Total positives :  84
# Probability of disease given test says positive :  0.10714285714285714
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  7
# Number of incorrect test positives :  83
# Total positives :  90
# Probability of disease given test says positive :  0.07777777777777778
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  77
# Total positives :  85
# Probability of disease given test says positive :  0.09411764705882353
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  77
# Total positives :  86
# Probability of disease given test says positive :  0.10465116279069768
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  78
# Total positives :  88
# Probability of disease given test says positive :  0.11363636363636363
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  8
# Number of incorrect test positives :  64
# Total positives :  72
# Probability of disease given test says positive :  0.1111111111111111
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  12
# Number of incorrect test positives :  75
# Total positives :  87
# Probability of disease given test says positive :  0.13793103448275862
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  10
# Number of incorrect test positives :  82
# Total positives :  92
# Probability of disease given test says positive :  0.10869565217391304
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  11
# Number of incorrect test positives :  70
# Total positives :  81
# Probability of disease given test says positive :  0.13580246913580246
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  9
# Number of incorrect test positives :  81
# Total positives :  90
# Probability of disease given test says positive :  0.1
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  7
# Number of incorrect test positives :  88
# Total positives :  95
# Probability of disease given test says positive :  0.07368421052631578
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  5
# Number of incorrect test positives :  76
# Total positives :  81
# Probability of disease given test says positive :  0.06172839506172839
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  6
# Number of incorrect test positives :  83
# Total positives :  89
# Probability of disease given test says positive :  0.06741573033707865
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  7
# Number of incorrect test positives :  70
# Total positives :  77
# Probability of disease given test says positive :  0.09090909090909091
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  74
# Total positives :  80
# Probability of disease given test says positive :  0.075
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  78
# Total positives :  84
# Probability of disease given test says positive :  0.07142857142857142
# --------------------------------------------------
# Population :  1000
# Number of cases :  3
# Number of correct test positives :  2
# Number of incorrect test positives :  72
# Total positives :  74
# Probability of disease given test says positive :  0.02702702702702703
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  74
# Total positives :  83
# Probability of disease given test says positive :  0.10843373493975904
# --------------------------------------------------
# Population :  1000
# Number of cases :  3
# Number of correct test positives :  3
# Number of incorrect test positives :  81
# Total positives :  84
# Probability of disease given test says positive :  0.03571428571428571
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  6
# Number of incorrect test positives :  85
# Total positives :  91
# Probability of disease given test says positive :  0.06593406593406594
# --------------------------------------------------
# Population :  1000
# Number of cases :  3
# Number of correct test positives :  3
# Number of incorrect test positives :  64
# Total positives :  67
# Probability of disease given test says positive :  0.04477611940298507
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  7
# Number of incorrect test positives :  84
# Total positives :  91
# Probability of disease given test says positive :  0.07692307692307693
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  4
# Number of incorrect test positives :  81
# Total positives :  85
# Probability of disease given test says positive :  0.047058823529411764
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  81
# Total positives :  91
# Probability of disease given test says positive :  0.10989010989010989
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  11
# Number of incorrect test positives :  80
# Total positives :  91
# Probability of disease given test says positive :  0.12087912087912088
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  9
# Number of incorrect test positives :  83
# Total positives :  92
# Probability of disease given test says positive :  0.09782608695652174
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  81
# Total positives :  87
# Probability of disease given test says positive :  0.06896551724137931
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  79
# Total positives :  87
# Probability of disease given test says positive :  0.09195402298850575
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  89
# Total positives :  100
# Probability of disease given test says positive :  0.11
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  5
# Number of incorrect test positives :  68
# Total positives :  73
# Probability of disease given test says positive :  0.0684931506849315
# --------------------------------------------------
# Population :  1000
# Number of cases :  14
# Number of correct test positives :  11
# Number of incorrect test positives :  83
# Total positives :  94
# Probability of disease given test says positive :  0.11702127659574468
# --------------------------------------------------
# Population :  1000
# Number of cases :  15
# Number of correct test positives :  13
# Number of incorrect test positives :  87
# Total positives :  100
# Probability of disease given test says positive :  0.13
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  78
# Total positives :  88
# Probability of disease given test says positive :  0.11363636363636363
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  66
# Total positives :  75
# Probability of disease given test says positive :  0.12
# --------------------------------------------------
# Population :  1000
# Number of cases :  14
# Number of correct test positives :  13
# Number of incorrect test positives :  80
# Total positives :  93
# Probability of disease given test says positive :  0.13978494623655913
# --------------------------------------------------
# Population :  1000
# Number of cases :  15
# Number of correct test positives :  15
# Number of incorrect test positives :  94
# Total positives :  109
# Probability of disease given test says positive :  0.13761467889908258
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  11
# Number of incorrect test positives :  85
# Total positives :  96
# Probability of disease given test says positive :  0.11458333333333333
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  11
# Number of incorrect test positives :  74
# Total positives :  85
# Probability of disease given test says positive :  0.12941176470588237
# --------------------------------------------------
# Population :  1000
# Number of cases :  3
# Number of correct test positives :  3
# Number of incorrect test positives :  82
# Total positives :  85
# Probability of disease given test says positive :  0.03529411764705882
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  80
# Total positives :  89
# Probability of disease given test says positive :  0.10112359550561797
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  5
# Number of incorrect test positives :  79
# Total positives :  84
# Probability of disease given test says positive :  0.05952380952380952
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  6
# Number of incorrect test positives :  70
# Total positives :  76
# Probability of disease given test says positive :  0.07894736842105263
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  9
# Number of incorrect test positives :  88
# Total positives :  97
# Probability of disease given test says positive :  0.09278350515463918
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  84
# Total positives :  90
# Probability of disease given test says positive :  0.06666666666666667
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  7
# Number of incorrect test positives :  74
# Total positives :  81
# Probability of disease given test says positive :  0.08641975308641975
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  7
# Number of incorrect test positives :  73
# Total positives :  80
# Probability of disease given test says positive :  0.0875
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  8
# Number of incorrect test positives :  75
# Total positives :  83
# Probability of disease given test says positive :  0.0963855421686747
# --------------------------------------------------
# Population :  1000
# Number of cases :  16
# Number of correct test positives :  13
# Number of incorrect test positives :  78
# Total positives :  91
# Probability of disease given test says positive :  0.14285714285714285
# --------------------------------------------------
# Population :  1000
# Number of cases :  15
# Number of correct test positives :  13
# Number of incorrect test positives :  79
# Total positives :  92
# Probability of disease given test says positive :  0.14130434782608695
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  12
# Number of incorrect test positives :  78
# Total positives :  90
# Probability of disease given test says positive :  0.13333333333333333
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  5
# Number of incorrect test positives :  86
# Total positives :  91
# Probability of disease given test says positive :  0.054945054945054944
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  6
# Number of incorrect test positives :  102
# Total positives :  108
# Probability of disease given test says positive :  0.05555555555555555
# --------------------------------------------------
# Population :  1000
# Number of cases :  19
# Number of correct test positives :  17
# Number of incorrect test positives :  88
# Total positives :  105
# Probability of disease given test says positive :  0.1619047619047619
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  79
# Total positives :  87
# Probability of disease given test says positive :  0.09195402298850575
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  89
# Total positives :  95
# Probability of disease given test says positive :  0.06315789473684211
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  7
# Number of incorrect test positives :  80
# Total positives :  87
# Probability of disease given test says positive :  0.08045977011494253
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  11
# Number of incorrect test positives :  82
# Total positives :  93
# Probability of disease given test says positive :  0.11827956989247312
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  10
# Number of incorrect test positives :  60
# Total positives :  70
# Probability of disease given test says positive :  0.14285714285714285
# --------------------------------------------------
# Population :  1000
# Number of cases :  14
# Number of correct test positives :  14
# Number of incorrect test positives :  76
# Total positives :  90
# Probability of disease given test says positive :  0.15555555555555556
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  70
# Total positives :  78
# Probability of disease given test says positive :  0.10256410256410256
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  69
# Total positives :  77
# Probability of disease given test says positive :  0.1038961038961039
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  79
# Total positives :  87
# Probability of disease given test says positive :  0.09195402298850575
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  9
# Number of incorrect test positives :  74
# Total positives :  83
# Probability of disease given test says positive :  0.10843373493975904
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  92
# Total positives :  103
# Probability of disease given test says positive :  0.10679611650485436
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  5
# Number of incorrect test positives :  80
# Total positives :  85
# Probability of disease given test says positive :  0.058823529411764705
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  7
# Number of incorrect test positives :  79
# Total positives :  86
# Probability of disease given test says positive :  0.08139534883720931
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  12
# Number of incorrect test positives :  82
# Total positives :  94
# Probability of disease given test says positive :  0.1276595744680851
# --------------------------------------------------
# Population :  1000
# Number of cases :  15
# Number of correct test positives :  13
# Number of incorrect test positives :  68
# Total positives :  81
# Probability of disease given test says positive :  0.16049382716049382
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  12
# Number of incorrect test positives :  81
# Total positives :  93
# Probability of disease given test says positive :  0.12903225806451613
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  10
# Number of incorrect test positives :  74
# Total positives :  84
# Probability of disease given test says positive :  0.11904761904761904
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  9
# Number of incorrect test positives :  89
# Total positives :  98
# Probability of disease given test says positive :  0.09183673469387756
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  5
# Number of incorrect test positives :  89
# Total positives :  94
# Probability of disease given test says positive :  0.05319148936170213
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  90
# Total positives :  101
# Probability of disease given test says positive :  0.10891089108910891
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  11
# Number of incorrect test positives :  76
# Total positives :  87
# Probability of disease given test says positive :  0.12643678160919541
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  76
# Total positives :  82
# Probability of disease given test says positive :  0.07317073170731707
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  8
# Number of incorrect test positives :  69
# Total positives :  77
# Probability of disease given test says positive :  0.1038961038961039
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  83
# Total positives :  94
# Probability of disease given test says positive :  0.11702127659574468
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  5
# Number of incorrect test positives :  76
# Total positives :  81
# Probability of disease given test says positive :  0.06172839506172839
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  10
# Number of incorrect test positives :  83
# Total positives :  93
# Probability of disease given test says positive :  0.10752688172043011
# --------------------------------------------------
# Population :  1000
# Number of cases :  4
# Number of correct test positives :  3
# Number of incorrect test positives :  73
# Total positives :  76
# Probability of disease given test says positive :  0.039473684210526314
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  75
# Total positives :  81
# Probability of disease given test says positive :  0.07407407407407407
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  80
# Total positives :  86
# Probability of disease given test says positive :  0.06976744186046512
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  63
# Total positives :  71
# Probability of disease given test says positive :  0.11267605633802817
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  12
# Number of incorrect test positives :  82
# Total positives :  94
# Probability of disease given test says positive :  0.1276595744680851
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  7
# Number of incorrect test positives :  87
# Total positives :  94
# Probability of disease given test says positive :  0.07446808510638298
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  86
# Total positives :  95
# Probability of disease given test says positive :  0.09473684210526316
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  5
# Number of incorrect test positives :  63
# Total positives :  68
# Probability of disease given test says positive :  0.07352941176470588
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  4
# Number of incorrect test positives :  94
# Total positives :  98
# Probability of disease given test says positive :  0.04081632653061224
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  7
# Number of incorrect test positives :  74
# Total positives :  81
# Probability of disease given test says positive :  0.08641975308641975
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  76
# Total positives :  85
# Probability of disease given test says positive :  0.10588235294117647
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  9
# Number of incorrect test positives :  80
# Total positives :  89
# Probability of disease given test says positive :  0.10112359550561797
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  10
# Number of incorrect test positives :  82
# Total positives :  92
# Probability of disease given test says positive :  0.10869565217391304
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  6
# Number of incorrect test positives :  68
# Total positives :  74
# Probability of disease given test says positive :  0.08108108108108109
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  84
# Total positives :  94
# Probability of disease given test says positive :  0.10638297872340426
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  8
# Number of incorrect test positives :  95
# Total positives :  103
# Probability of disease given test says positive :  0.07766990291262135
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  4
# Number of incorrect test positives :  82
# Total positives :  86
# Probability of disease given test says positive :  0.046511627906976744
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  63
# Total positives :  71
# Probability of disease given test says positive :  0.11267605633802817
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  9
# Number of incorrect test positives :  78
# Total positives :  87
# Probability of disease given test says positive :  0.10344827586206896
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  69
# Total positives :  78
# Probability of disease given test says positive :  0.11538461538461539
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  91
# Total positives :  99
# Probability of disease given test says positive :  0.08080808080808081
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  6
# Number of incorrect test positives :  95
# Total positives :  101
# Probability of disease given test says positive :  0.0594059405940594
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  4
# Number of incorrect test positives :  87
# Total positives :  91
# Probability of disease given test says positive :  0.04395604395604396
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  69
# Total positives :  78
# Probability of disease given test says positive :  0.11538461538461539
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  7
# Number of incorrect test positives :  72
# Total positives :  79
# Probability of disease given test says positive :  0.08860759493670886
# --------------------------------------------------
# Population :  1000
# Number of cases :  4
# Number of correct test positives :  3
# Number of incorrect test positives :  79
# Total positives :  82
# Probability of disease given test says positive :  0.036585365853658534
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  7
# Number of incorrect test positives :  84
# Total positives :  91
# Probability of disease given test says positive :  0.07692307692307693
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  8
# Number of incorrect test positives :  84
# Total positives :  92
# Probability of disease given test says positive :  0.08695652173913043
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  6
# Number of incorrect test positives :  63
# Total positives :  69
# Probability of disease given test says positive :  0.08695652173913043
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  11
# Number of incorrect test positives :  71
# Total positives :  82
# Probability of disease given test says positive :  0.13414634146341464
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  82
# Total positives :  93
# Probability of disease given test says positive :  0.11827956989247312
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  5
# Number of incorrect test positives :  79
# Total positives :  84
# Probability of disease given test says positive :  0.05952380952380952
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  7
# Number of incorrect test positives :  83
# Total positives :  90
# Probability of disease given test says positive :  0.07777777777777778
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  68
# Total positives :  78
# Probability of disease given test says positive :  0.1282051282051282
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  6
# Number of incorrect test positives :  79
# Total positives :  85
# Probability of disease given test says positive :  0.07058823529411765
# --------------------------------------------------
# Population :  1000
# Number of cases :  14
# Number of correct test positives :  11
# Number of incorrect test positives :  78
# Total positives :  89
# Probability of disease given test says positive :  0.12359550561797752
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  81
# Total positives :  91
# Probability of disease given test says positive :  0.10989010989010989
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  8
# Number of incorrect test positives :  74
# Total positives :  82
# Probability of disease given test says positive :  0.0975609756097561
# ...
# Number of correct test positives :  8
# Number of incorrect test positives :  70
# Total positives :  78
# Probability of disease given test says positive :  0.10256410256410256
# --------------------------------------------------
# Population :  1000
# Number of cases :  15
# Number of correct test positives :  15
# Number of incorrect test positives :  70
# Total positives :  85
# Probability of disease given test says positive :  0.17647058823529413
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  9
# Number of incorrect test positives :  76
# Total positives :  85
# Probability of disease given test says positive :  0.10588235294117647
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  10
# Number of incorrect test positives :  71
# Total positives :  81
# Probability of disease given test says positive :  0.12345679012345678
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  65
# Total positives :  74
# Probability of disease given test says positive :  0.12162162162162163
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  8
# Number of incorrect test positives :  84
# Total positives :  92
# Probability of disease given test says positive :  0.08695652173913043
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  8
# Number of incorrect test positives :  73
# Total positives :  81
# Probability of disease given test says positive :  0.09876543209876543
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  12
# Number of incorrect test positives :  85
# Total positives :  97
# Probability of disease given test says positive :  0.12371134020618557
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  8
# Number of incorrect test positives :  80
# Total positives :  88
# Probability of disease given test says positive :  0.09090909090909091
# --------------------------------------------------
# Population :  1000
# Number of cases :  14
# Number of correct test positives :  12
# Number of incorrect test positives :  79
# Total positives :  91
# Probability of disease given test says positive :  0.13186813186813187
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  11
# Number of incorrect test positives :  78
# Total positives :  89
# Probability of disease given test says positive :  0.12359550561797752
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  10
# Number of incorrect test positives :  85
# Total positives :  95
# Probability of disease given test says positive :  0.10526315789473684
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  6
# Number of incorrect test positives :  70
# Total positives :  76
# Probability of disease given test says positive :  0.07894736842105263
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  8
# Number of incorrect test positives :  72
# Total positives :  80
# Probability of disease given test says positive :  0.1
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  10
# Number of incorrect test positives :  78
# Total positives :  88
# Probability of disease given test says positive :  0.11363636363636363
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  7
# Number of incorrect test positives :  77
# Total positives :  84
# Probability of disease given test says positive :  0.08333333333333333
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  12
# Number of incorrect test positives :  70
# Total positives :  82
# Probability of disease given test says positive :  0.14634146341463414
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  6
# Number of incorrect test positives :  74
# Total positives :  80
# Probability of disease given test says positive :  0.075
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  80
# Total positives :  89
# Probability of disease given test says positive :  0.10112359550561797
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  9
# Number of incorrect test positives :  80
# Total positives :  89
# Probability of disease given test says positive :  0.10112359550561797
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  13
# Number of incorrect test positives :  85
# Total positives :  98
# Probability of disease given test says positive :  0.1326530612244898
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  9
# Number of incorrect test positives :  88
# Total positives :  97
# Probability of disease given test says positive :  0.09278350515463918
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  77
# Total positives :  88
# Probability of disease given test says positive :  0.125
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  5
# Number of incorrect test positives :  75
# Total positives :  80
# Probability of disease given test says positive :  0.0625
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  89
# Total positives :  98
# Probability of disease given test says positive :  0.09183673469387756
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  10
# Number of incorrect test positives :  75
# Total positives :  85
# Probability of disease given test says positive :  0.11764705882352941
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  8
# Number of incorrect test positives :  88
# Total positives :  96
# Probability of disease given test says positive :  0.08333333333333333
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  7
# Number of incorrect test positives :  76
# Total positives :  83
# Probability of disease given test says positive :  0.08433734939759036
# --------------------------------------------------
# Population :  1000
# Number of cases :  11
# Number of correct test positives :  11
# Number of incorrect test positives :  78
# Total positives :  89
# Probability of disease given test says positive :  0.12359550561797752
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  12
# Number of incorrect test positives :  75
# Total positives :  87
# Probability of disease given test says positive :  0.13793103448275862
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  9
# Number of incorrect test positives :  70
# Total positives :  79
# Probability of disease given test says positive :  0.11392405063291139
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  12
# Number of incorrect test positives :  97
# Total positives :  109
# Probability of disease given test says positive :  0.11009174311926606
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  5
# Number of incorrect test positives :  82
# Total positives :  87
# Probability of disease given test says positive :  0.05747126436781609
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  12
# Number of incorrect test positives :  78
# Total positives :  90
# Probability of disease given test says positive :  0.13333333333333333
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  4
# Number of incorrect test positives :  89
# Total positives :  93
# Probability of disease given test says positive :  0.043010752688172046
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  75
# Total positives :  85
# Probability of disease given test says positive :  0.11764705882352941
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  13
# Number of incorrect test positives :  71
# Total positives :  84
# Probability of disease given test says positive :  0.15476190476190477
# --------------------------------------------------
# Population :  1000
# Number of cases :  2
# Number of correct test positives :  2
# Number of incorrect test positives :  73
# Total positives :  75
# Probability of disease given test says positive :  0.02666666666666667
# --------------------------------------------------
# Population :  1000
# Number of cases :  14
# Number of correct test positives :  13
# Number of incorrect test positives :  73
# Total positives :  86
# Probability of disease given test says positive :  0.1511627906976744
# --------------------------------------------------
# Population :  1000
# Number of cases :  9
# Number of correct test positives :  9
# Number of incorrect test positives :  61
# Total positives :  70
# Probability of disease given test says positive :  0.12857142857142856
# --------------------------------------------------
# Population :  1000
# Number of cases :  14
# Number of correct test positives :  10
# Number of incorrect test positives :  77
# Total positives :  87
# Probability of disease given test says positive :  0.11494252873563218
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  6
# Number of incorrect test positives :  82
# Total positives :  88
# Probability of disease given test says positive :  0.06818181818181818
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  9
# Number of incorrect test positives :  75
# Total positives :  84
# Probability of disease given test says positive :  0.10714285714285714
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  12
# Number of incorrect test positives :  77
# Total positives :  89
# Probability of disease given test says positive :  0.1348314606741573
# --------------------------------------------------
# Population :  1000
# Number of cases :  10
# Number of correct test positives :  10
# Number of incorrect test positives :  87
# Total positives :  97
# Probability of disease given test says positive :  0.10309278350515463
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  7
# Number of incorrect test positives :  102
# Total positives :  109
# Probability of disease given test says positive :  0.06422018348623854
# --------------------------------------------------
# Population :  1000
# Number of cases :  7
# Number of correct test positives :  6
# Number of incorrect test positives :  81
# Total positives :  87
# Probability of disease given test says positive :  0.06896551724137931
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  7
# Number of incorrect test positives :  86
# Total positives :  93
# Probability of disease given test says positive :  0.07526881720430108
# --------------------------------------------------
# Population :  1000
# Number of cases :  15
# Number of correct test positives :  13
# Number of incorrect test positives :  79
# Total positives :  92
# Probability of disease given test says positive :  0.14130434782608695
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  74
# Total positives :  85
# Probability of disease given test says positive :  0.12941176470588237
# --------------------------------------------------
# Population :  1000
# Number of cases :  17
# Number of correct test positives :  13
# Number of incorrect test positives :  68
# Total positives :  81
# Probability of disease given test says positive :  0.16049382716049382
# --------------------------------------------------
# Population :  1000
# Number of cases :  8
# Number of correct test positives :  8
# Number of incorrect test positives :  87
# Total positives :  95
# Probability of disease given test says positive :  0.08421052631578947
# --------------------------------------------------
# Population :  1000
# Number of cases :  5
# Number of correct test positives :  5
# Number of incorrect test positives :  68
# Total positives :  73
# Probability of disease given test says positive :  0.0684931506849315
# --------------------------------------------------
# Population :  1000
# Number of cases :  14
# Number of correct test positives :  12
# Number of incorrect test positives :  84
# Total positives :  96
# Probability of disease given test says positive :  0.125
# --------------------------------------------------
# Population :  1000
# Number of cases :  17
# Number of correct test positives :  14
# Number of incorrect test positives :  61
# Total positives :  75
# Probability of disease given test says positive :  0.18666666666666668
# --------------------------------------------------
# Population :  1000
# Number of cases :  15
# Number of correct test positives :  15
# Number of incorrect test positives :  101
# Total positives :  116
# Probability of disease given test says positive :  0.12931034482758622
# --------------------------------------------------
# Population :  1000
# Number of cases :  13
# Number of correct test positives :  12
# Number of incorrect test positives :  69
# Total positives :  81
# Probability of disease given test says positive :  0.14814814814814814
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  84
# Total positives :  90
# Probability of disease given test says positive :  0.06666666666666667
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  12
# Number of incorrect test positives :  67
# Total positives :  79
# Probability of disease given test says positive :  0.1518987341772152
# --------------------------------------------------
# Population :  1000
# Number of cases :  6
# Number of correct test positives :  6
# Number of incorrect test positives :  94
# Total positives :  100
# Probability of disease given test says positive :  0.06
# --------------------------------------------------
# Population :  1000
# Number of cases :  12
# Number of correct test positives :  11
# Number of incorrect test positives :  65
# Total positives :  76
# Probability of disease given test says positive :  0.14473684210526316
# --------------------------------------------------

# %%
np.mean(p_disease_given_test_positive)
# Out:
# 0.10254675395560564

# %%
# Why closed form solutions matter?
# Why we need simulations if closed form solutions aren't possible?

# If we roll three dice, what is the probability that their total is 8?

# We could count all the possibilities, or we could get an approximate answer via simulation.

# importing numpy
import numpy as np
import random
np.random.seed(1234)

def roll_dice(num_dice):
    """Return a list of integers with length `num_dice`.

    Each integer in the returned list is a random number between
    1 and 6, inclusive.
    """
    roll_results = []
    for i in range(num_dice):
        roll = random.randint(1, 6)
        roll_results.append(roll)
    return roll_results

def sum_simulation(num_dice, k, nreps):
    sums = np.zeros(nreps)
    for rep in range(nreps):
     sums[rep]=sum(roll_dice(num_dice))
    return np.count_nonzero(sums == k)/nreps

# %%
simulation_result=sum_simulation(2, 7, 10) #10 repetitions
print(simulation_result)

simulation_result=sum_simulation(2, 7, 100) #100 repetitions
print(simulation_result)

simulation_result=sum_simulation(2, 7, 100) #1000 repetitions
print(simulation_result)

simulation_result=sum_simulation(2, 7, 100000) #100,000 repetitions
print(simulation_result)
# Out:
# 0.0
# 0.24
# 0.14
# 0.16791
